# %%
import pandas as pd
import numpy as np

# %%
filedata = pd.read_csv("Market_Basket_Optimisation.csv")

# %%
filedata.shape
# Out:
# (7500, 20)

# %%
filedata.head()
# Out:
#            shrimp    almonds     avocado  ... frozen smoothie spinach olive oil
# 0         burgers  meatballs        eggs  ...             NaN     NaN       NaN
# 1         chutney        NaN         NaN  ...             NaN     NaN       NaN
# 2          turkey    avocado         NaN  ...             NaN     NaN       NaN
# 3   mineral water       milk  energy bar  ...             NaN     NaN       NaN
# 4  low fat yogurt        NaN         NaN  ...             NaN     NaN       NaN
#
# [5 rows x 20 columns]

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
records = []
for i in range (0,7500):
  records.append([str(filedata.values[i,j]) for j in range (0,20)])

# %%
te = TransactionEncoder()

# %%
te_array = te.fit(records).transform(records)
te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df = pd.DataFrame(te_array,columns=te.columns_)

# %%
df
# Out:
#        asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0          False    False              False  ...  False        False     False
# 1          False    False              False  ...  False        False     False
# 2          False    False              False  ...  False        False     False
# 3          False    False              False  ...  False        False     False
# 4          False    False              False  ...  False        False     False
# ...          ...      ...                ...  ...    ...          ...       ...
# 7495       False    False              False  ...  False        False     False
# 7496       False    False              False  ...  False        False     False
# 7497       False    False              False  ...  False        False     False
# 7498       False    False              False  ...  False        False     False
# 7499       False    False              False  ...  False         True     False
#
# ...

# %%
pip install pyfpgrowth

# %%
import pyfpgrowth as fp

# %%
frequent_pattern = fp.find_frequent_patterns(df,40)

# %%
frequent_pattern
# Out:
# {(' ', 'a'): 79,
#  (' ', 'a', 'a', 'e', 'o', 't'): 88,
#  (' ', 'a', 'a', 'o', 't'): 50,
#  (' ', 'a', 'e'): 135,
#  (' ', 'a', 'e', 'e', 'o', 't'): 74,
#  (' ', 'a', 'e', 'o'): 110,
#  (' ', 'a', 'e', 'o', 'r'): 125,
#  (' ', 'a', 'e', 'o', 't'): 142,
#  (' ', 'a', 'e', 'r'): 152,
#  (' ', 'a', 'e', 'r', 's'): 100,
#  (' ', 'a', 'e', 'r', 't'): 129,
#  (' ', 'a', 'e', 's'): 99,
#  (' ', 'a', 'e', 't'): 137,
#  (' ', 'a', 'o'): 69,
#  (' ', 'a', 'o', 'r'): 71,
#  (' ', 'a', 'o', 't'): 91,
#  (' ', 'a', 'r'): 85,
#  (' ', 'a', 'r', 's'): 54,
#  (' ', 'a', 'r', 't'): 71,
#  (' ', 'a', 's'): 53,
#  (' ', 'a', 't'): 79,
#  (' ', 'e'): 123,
#  (' ', 'e', 'e'): 93,
#  (' ', 'e', 'e', 'o'): 47,
#  (' ', 'e', 'e', 'o', 'r'): 47,
#  (' ', 'e', 'e', 'o', 't'): 54,
#  (' ', 'e', 'e', 'r'): 105,
#  (' ', 'e', 'e', 'r', 's'): 75,
#  (' ', 'e', 'e', 'r', 't'): 68,
#  (' ', 'e', 'e', 's'): 77,
#  (' ', 'e', 'e', 't'): 77,
#  (' ', 'e', 'o'): 81,
#  (' ', 'e', 'o', 'r'): 79,
# ...

# %%
rules = fp.generate_association_rules(frequent_pattern,0.75)

# %%
rules
# Out:
# {(' ', 'a'): (('e',), 1.7088607594936709),
#  (' ', 'a', 'a', 'o', 't'): (('e',), 1.76),
#  (' ', 'a', 'e'): (('r',), 1.125925925925926),
#  (' ', 'a', 'e', 'o'): (('r',), 1.1363636363636365),
#  (' ', 'a', 'e', 'r'): (('o',), 0.8223684210526315),
#  (' ', 'a', 'e', 's'): (('r',), 1.0101010101010102),
#  (' ', 'a', 'e', 't'): (('o',), 1.0364963503649636),
#  (' ', 'a', 'o'): (('e',), 1.5942028985507246),
#  (' ', 'a', 'o', 'r'): (('e',), 1.7605633802816902),
#  (' ', 'a', 'o', 't'): (('e',), 0.967032967032967),
#  (' ', 'a', 'r'): (('e',), 1.7882352941176471),
#  (' ', 'a', 'r', 's'): (('e',), 1.8518518518518519),
#  (' ', 'a', 'r', 't'): (('e',), 1.8169014084507042),
#  (' ', 'a', 's'): (('e',), 1.8679245283018868),
#  (' ', 'a', 't'): (('e',), 1.7341772151898733),
#  (' ', 'e'): ((), 0.7560975609756098),
#  (' ', 'e', 'e'): (('r',), 1.1290322580645162),
#  (' ', 'e', 'e', 'o'): (('r',), 1.0),
#  (' ', 'e', 'e', 'o', 't'): (('a',), 1.3703703703703705),
# ...
